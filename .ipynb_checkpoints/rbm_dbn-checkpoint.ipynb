# %%
import numpy as np
from sklearn.neural_network import BernoulliRBM
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.base import clone
from sklearn.metrics import classification_report
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # RBM Network

# %%
(x_train, y_train), (x_test, y_test)  = fashion_mnist.load_data()

print(x_train.shape)
# Out:
# (60000, 28, 28)

# %%
x_train = x_train / 255.0

n, x, y = x_train.shape
x_train = x_train.reshape((n, x * y))
print(x_train.shape)
# Out:
# (60000, 784)

# %%
rbm = BernoulliRBM(n_components=64, learning_rate=0.02, batch_size=128, n_iter=50, random_state=0, verbose=True)

# %%
# %%time
rbm.fit(x_train)
# Out:
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -296.89, time = 2.56s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -281.24, time = 3.65s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -272.70, time = 3.51s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -267.58, time = 3.66s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -263.88, time = 3.59s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -261.72, time = 3.73s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -259.58, time = 3.52s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -257.86, time = 3.52s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -255.82, time = 3.50s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -254.58, time = 3.48s
# [BernoulliRBM] Iteration 11, pseudo-likelihood = -252.67, time = 3.49s
# [BernoulliRBM] Iteration 12, pseudo-likelihood = -251.11, time = 3.47s
# [BernoulliRBM] Iteration 13, pseudo-likelihood = -250.26, time = 3.46s
# [BernoulliRBM] Iteration 14, pseudo-likelihood = -248.44, time = 3.65s
# [BernoulliRBM] Iteration 15, pseudo-likelihood = -246.62, time = 3.54s
# [BernoulliRBM] Iteration 16, pseudo-likelihood = -245.46, time = 3.52s
# [BernoulliRBM] Iteration 17, pseudo-likelihood = -244.09, time = 3.43s
# [BernoulliRBM] Iteration 18, pseudo-likelihood = -242.73, time = 3.64s
# [BernoulliRBM] Iteration 19, pseudo-likelihood = -241.52, time = 3.69s
# [BernoulliRBM] Iteration 20, pseudo-likelihood = -239.73, time = 3.60s
# [BernoulliRBM] Iteration 21, pseudo-likelihood = -238.69, time = 3.45s
# [BernoulliRBM] Iteration 22, pseudo-likelihood = -237.44, time = 3.60s
# [BernoulliRBM] Iteration 23, pseudo-likelihood = -235.73, time = 3.64s
# [BernoulliRBM] Iteration 24, pseudo-likelihood = -235.23, time = 3.52s
# [BernoulliRBM] Iteration 25, pseudo-likelihood = -233.12, time = 3.55s
# [BernoulliRBM] Iteration 26, pseudo-likelihood = -232.51, time = 3.47s
# [BernoulliRBM] Iteration 27, pseudo-likelihood = -231.22, time = 3.53s
# [BernoulliRBM] Iteration 28, pseudo-likelihood = -230.04, time = 3.44s
# [BernoulliRBM] Iteration 29, pseudo-likelihood = -228.57, time = 3.50s
# [BernoulliRBM] Iteration 30, pseudo-likelihood = -227.74, time = 3.42s
# [BernoulliRBM] Iteration 31, pseudo-likelihood = -226.66, time = 3.61s
# [BernoulliRBM] Iteration 32, pseudo-likelihood = -226.24, time = 3.52s
# [BernoulliRBM] Iteration 33, pseudo-likelihood = -224.90, time = 3.50s
# [BernoulliRBM] Iteration 34, pseudo-likelihood = -223.91, time = 3.50s
# [BernoulliRBM] Iteration 35, pseudo-likelihood = -223.34, time = 3.51s
# [BernoulliRBM] Iteration 36, pseudo-likelihood = -222.74, time = 3.44s
# [BernoulliRBM] Iteration 37, pseudo-likelihood = -222.29, time = 3.50s
# [BernoulliRBM] Iteration 38, pseudo-likelihood = -220.33, time = 3.48s
# [BernoulliRBM] Iteration 39, pseudo-likelihood = -219.95, time = 3.56s
# [BernoulliRBM] Iteration 40, pseudo-likelihood = -221.19, time = 3.68s
# [BernoulliRBM] Iteration 41, pseudo-likelihood = -219.67, time = 3.47s
# [BernoulliRBM] Iteration 42, pseudo-likelihood = -219.54, time = 3.46s
# [BernoulliRBM] Iteration 43, pseudo-likelihood = -218.76, time = 3.53s
# [BernoulliRBM] Iteration 44, pseudo-likelihood = -218.63, time = 3.47s
# [BernoulliRBM] Iteration 45, pseudo-likelihood = -218.61, time = 3.56s
# [BernoulliRBM] Iteration 46, pseudo-likelihood = -217.85, time = 3.57s
# [BernoulliRBM] Iteration 47, pseudo-likelihood = -216.96, time = 3.57s
# [BernoulliRBM] Iteration 48, pseudo-likelihood = -216.32, time = 3.73s
# [BernoulliRBM] Iteration 49, pseudo-likelihood = -216.51, time = 3.82s
# [BernoulliRBM] Iteration 50, pseudo-likelihood = -216.44, time = 3.56s
# Wall time: 2min 57s
# BernoulliRBM(batch_size=128, learning_rate=0.02, n_components=64, n_iter=50,
#              random_state=0, verbose=True)

# %%
rbm.components_.shape
# Out:
# (64, 784)

# %% [markdown]
# ## Visualization

# %%
def plot_imgs(data, title):
    plt.figure(figsize=(15, 10))
    for i, img in enumerate(data):
        plt.subplot(8, 8, i + 1)
        plt.imshow(img.reshape((28, 28)), cmap=plt.get_cmap('gray'))
        plt.xticks(())
        plt.yticks(())

    plt.suptitle(title)
    plt.show()

# %% [markdown]
# ### Original data

# %%
plot_imgs(x_train[:64], 'Original data')

# %% [markdown]
# ### Components

# %%
plot_imgs(rbm.components_, 'RBM Components')

# %% [markdown]
# ## Reconstruction

# %%
def iterate_gibbs(n, data, rbm):
    gibbs_data = data.copy()
    
    for i in range(n):
        gibbs_data = rbm.gibbs(gibbs_data).astype(float)
    
    return gibbs_data

# %%
gen_x = iterate_gibbs(1, x_train[:64], rbm)

# %%
plot_imgs(gen_x, 'Gibbs reconstruction')

# %% [markdown]
# ## Generating

# %%
n_samples = np.random.random_sample((64, 784))

# %%
plot_imgs(n_samples, 'Generated noise')

# %%
gen_nsamples = iterate_gibbs(1000, n_samples, rbm)

# %%
plot_imgs(gen_nsamples, 'Generated images')

# %% [markdown]
# # DBN Network classification

# %% [markdown]
# MNIST Fashion classification using stacked RBM

# %% [markdown]
# | Label | Description |
# | --- | --- |
# | 0 | T-shirt/top |
# | 1 | Trouser |
# | 2 | Pullover |
# | 3 | Dress |
# | 4 | Coat |
# | 5 | Sandal |
# | 6 | Shirt |
# | 7 | Sneaker |
# | 8 | Bag |
# | 9 | Ankle boot |

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

n, x, y = x_train.shape
x_train = x_train.reshape((n, x * y))
print(x_train.shape)

n, x, y = x_test.shape
x_test = x_test.reshape((n, x * y))
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# **DBN Model**

# %%
rbm = BernoulliRBM(n_components=140, learning_rate=0.02, batch_size=128, n_iter=50, verbose=True)

# %%
lg = LogisticRegression(C=10, multi_class='multinomial', solver='lbfgs', max_iter=1000, verbose=True)

# %%
model = Pipeline(steps=[('rbm', clone(rbm)), ('rbm2', clone(rbm)), ('clf', lg)])

# %%
model.fit(x_train, y_train)
# Out:
# [BernoulliRBM] Iteration 1, pseudo-likelihood =