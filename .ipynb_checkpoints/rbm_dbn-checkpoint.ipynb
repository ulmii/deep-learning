# [BernoulliRBM] Iteration 73, pseudo-likelihood = -204.08, time = 4.81s
# [BernoulliRBM] Iteration 74, pseudo-likelihood = -204.54, time = 4.91s
# [BernoulliRBM] Iteration 75, pseudo-likelihood = -203.07, time = 4.99s
# [BernoulliRBM] Iteration 76, pseudo-likelihood = -204.32, time = 4.90s
# [BernoulliRBM] Iteration 77, pseudo-likelihood = -203.08, time = 4.76s
# [BernoulliRBM] Iteration 78, pseudo-likelihood = -204.36, time = 4.82s
# [BernoulliRBM] Iteration 79, pseudo-likelihood = -207.36, time = 4.78s
# [BernoulliRBM] Iteration 80, pseudo-likelihood = -202.79, time = 4.83s
# [BernoulliRBM] Iteration 81, pseudo-likelihood = -205.20, time = 4.96s
# [BernoulliRBM] Iteration 82, pseudo-likelihood = -204.78, time = 4.84s
# [BernoulliRBM] Iteration 83, pseudo-likelihood = -203.44, time = 4.87s
# [BernoulliRBM] Iteration 84, pseudo-likelihood = -202.97, time = 4.82s
# [BernoulliRBM] Iteration 85, pseudo-likelihood = -205.32, time = 4.73s
# [BernoulliRBM] Iteration 86, pseudo-likelihood = -203.82, time = 4.87s
# [BernoulliRBM] Iteration 87, pseudo-likelihood = -202.82, time = 5.02s
# [BernoulliRBM] Iteration 88, pseudo-likelihood = -205.05, time = 4.89s
# [BernoulliRBM] Iteration 89, pseudo-likelihood = -204.14, time = 4.86s
# [BernoulliRBM] Iteration 90, pseudo-likelihood = -202.58, time = 4.79s
# [BernoulliRBM] Iteration 91, pseudo-likelihood = -203.26, time = 4.73s
# [BernoulliRBM] Iteration 92, pseudo-likelihood = -203.10, time = 4.87s
# [BernoulliRBM] Iteration 93, pseudo-likelihood = -203.46, time = 4.93s
# [BernoulliRBM] Iteration 94, pseudo-likelihood = -204.66, time = 4.91s
# [BernoulliRBM] Iteration 95, pseudo-likelihood = -204.90, time = 4.92s
# [BernoulliRBM] Iteration 96, pseudo-likelihood = -205.82, time = 4.71s
# [BernoulliRBM] Iteration 97, pseudo-likelihood = -202.98, time = 4.88s
# [BernoulliRBM] Iteration 98, pseudo-likelihood = -204.55, time = 4.95s
# [BernoulliRBM] Iteration 99, pseudo-likelihood = -202.96, time = 4.91s
# [BernoulliRBM] Iteration 100, pseudo-likelihood = -203.53, time = 4.95s
# Wall time: 8min 11s
# BernoulliRBM(batch_size=50, learning_rate=0.02, n_components=64, n_iter=100,
#              random_state=0, verbose=True)

# %%
rbm.components_.shape
# Out:
# (64, 784)

# %% [markdown]
# ## Visualization

# %%
def plot_imgs(data, title):
    plt.figure(figsize=(15, 10))
    for i, img in enumerate(data):
        plt.subplot(8, 8, i + 1)
        plt.imshow(img.reshape((28, 28)), cmap=plt.get_cmap('gray'))
        plt.xticks(())
        plt.yticks(())

    plt.suptitle(title)
    plt.show()

# %% [markdown]
# ### Original data

# %%
plot_imgs(x_train[:64], 'Original data')

# %% [markdown]
# ### Components

# %%
plot_imgs(rbm.components_, 'RBM Components')

# %% [markdown]
# ## Reconstruction

# %%
def iterate_gibbs(n, data, rbm):
    gibbs_data = data.copy()
    
    for i in range(n):
        gibbs_data = rbm.gibbs(gibbs_data).astype(float)
    
    return gibbs_data

# %%
gen_x = iterate_gibbs(1, x_train[:64], rbm)

# %%
plot_imgs(gen_x, 'Gibbs reconstruction')

# %% [markdown]
# ## Generating

# %%
n_samples = np.random.random_sample((64, 784))

# %%
plot_imgs(n_samples, 'Generated noise')

# %%
gen_nsamples = iterate_gibbs(1000, n_samples, rbm)

# %%
plot_imgs(gen_nsamples, 'Generated images')
